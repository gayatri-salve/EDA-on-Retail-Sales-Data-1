# %% [markdown]
# #IMPORTING THE LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#LOADING DATA

# %%
data = pd.read_csv('D:/retail_sales_dataset.csv')
data
# Out:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  24-11-2023     CUST001    Male   34           Beauty
# 1                 2  27-02-2023     CUST002  Female   26         Clothing
# 2                 3  13-01-2023     CUST003    Male   50      Electronics
# 3                 4  21-05-2023     CUST004    Male   37         Clothing
# 4                 5  06-05-2023     CUST005    Male   30           Beauty
# ..              ...         ...         ...     ...  ...              ...
# 995             996  16-05-2023     CUST996    Male   62         Clothing
# 996             997  17-11-2023     CUST997    Male   52           Beauty
# 997             998  29-10-2023     CUST998  Female   23           Beauty
# 998             999  05-12-2023     CUST999  Female   36      Electronics
# 999            1000  12-04-2023    CUST1000    Male   47      Electronics
#
#      Quantity  Price per Unit  Total Amount
# ...

# %%
#CLEANING DATA

# %%
data.count()
# Out:
# Transaction ID      1000
# Date                1000
# Customer ID         1000
# Gender              1000
# Age                 1000
# Product Category    1000
# Quantity            1000
# Price per Unit      1000
# Total Amount        1000
# dtype: int64

# %%
# Check for duplicates
duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
# Check for missing values
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
print(data.head())
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  24-11-2023     CUST001    Male   34           Beauty
# 1               2  27-02-2023     CUST002  Female   26         Clothing
# 2               3  13-01-2023     CUST003    Male   50      Electronics
# 3               4  21-05-2023     CUST004    Male   37         Clothing
# 4               5  06-05-2023     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
#DISCRIPTIVE STATISTICS

# %%
# Basic statistics for numeric columns

mean_sales = data['Total Amount'].mean()
median_sales = data['Total Amount'].median()
mode_sales = data['Total Amount'].mode()[0]  # Mode might have multiple values
std_dev_sales = data['Total Amount'].std()

print(f"Mean Sales: {mean_sales}")
print(f"Median Sales: {median_sales}")
print(f"Mode Sales: {mode_sales}")
print(f"Standard Deviation of Sales: {std_dev_sales}")
# Out:
# Mean Sales: 456.0
# Median Sales: 135.0
# Mode Sales: 50
# Standard Deviation of Sales: 559.997631555123

# %%
#TIME SERIES ANALYSIS

# %%
# Time Series Analysis
plt.figure(figsize=(10,6))
sns.lineplot(x='Date', y='Total Amount', data=data)
plt.title('Time Series Analysis of Total Amount')
plt.xlabel('Date')
plt.ylabel('Total Amount')
plt.show()

# %%
#VISUALIZATION

# %%
# Customer and Product Analysis
plt.figure(figsize=(10,6))
sns.countplot(x='Product Category', data=data)
plt.title('Product Category Distribution')
plt.xlabel('Product Category')
plt.ylabel('Count')
plt.show()

gender_distribution = data['Gender'].value_counts()

plt.figure(figsize=(8, 5))
sns.barplot(x=gender_distribution.index, y=gender_distribution.values)
plt.title('Gender Distribution of Customers')
plt.xlabel('Gender')
plt.ylabel('Number of Customers')
plt.show()

plt.figure(figsize=(10,6))
sns.scatterplot(x='Quantity', y='Price per Unit', data=data)
plt.title('Quantity vs Price per Unit')
plt.xlabel('Quantity')
plt.ylabel('Price per Unit')
plt.show()

# %%
# Heatmap
plt.figure(figsize=(10,6))
numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns
sns.heatmap(data[numeric_cols].corr(), annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Heatmap')
plt.show()

# Age distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], kde=True, bins=20)
plt.title('Age Distribution of Customers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #RECOMMENDATIONS:

# %% [markdown]
# Based on the EDA, here are some actionable recommendations:
# 1)Targeted Marketing: The analysis shows that males and females have different product preferences.The company can create targeted marketing campaigns to appeal to these preferences.
# 2)Age-Based Discounts: The analysis shows that customers of different age groups have different purchasing habits. The company can offer age-based discounts to attract more customers from different age groups.
# 3)Seasonal Demand: The analysis shows that sales vary by month. The company can analyze seasonal demand and adjust its inventory and marketing strategies accordingly.
# 4)Customer Segmentation: The analysis shows that customers can be segmented based on demographics and purchasing habits. The company can create customer segments and tailor its marketing strategies to each segment.
